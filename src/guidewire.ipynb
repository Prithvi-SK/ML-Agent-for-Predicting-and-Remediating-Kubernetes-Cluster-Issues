# %%
try:
    import pandas as pd
except ImportError:
    import subprocess
    import sys
    subprocess.check_call([sys.executable, "-m", "pip", "install", "pandas"])
    import pandas as pd

df = pd.read_csv("../data/dataSynthetic.csv")

# %%
df.head()
# Out:
#              Timestamp                                           Pod Name  \
# 0  2024-04-19 21:05:48          opentelemetry-demo-redis-68779558bb-4mjtr
# 1  2024-04-19 20:58:41       opentelemetry-demo-frontend-76f486559f-szlsh
# 2  2024-04-18 22:13:38  opentelemetry-demo-frauddetectionservice-64cb6...
# 3  2024-04-22 12:30:14  opentelemetry-demo-frauddetectionservice-64cb6...
# 4  2024-04-22 15:54:45  opentelemetry-demo-recommendationservice-7697d...
#
#    CPU Usage (%)  Memory Usage (%) Pod Status  Pod Reason  Pod Restarts  \
# 0       0.230313         53.101612    Running         NaN             0
# 1      14.612577          0.141409    Running         NaN             2
# 2       0.603365         12.191371    Running         NaN             0
# 3       0.077004          0.201204    Unknown         NaN             0
# 4       1.060736         43.678164    Running         NaN             0
#
#    Ready Containers  Total Containers    Pod Event Type Pod Event Reason  \
# ...

# %%
df=df.drop(columns=['Pod Reason'])

# %%
df.head()
# Out:
#              Timestamp                                           Pod Name  \
# 0  2024-04-19 21:05:48          opentelemetry-demo-redis-68779558bb-4mjtr
# 1  2024-04-19 20:58:41       opentelemetry-demo-frontend-76f486559f-szlsh
# 2  2024-04-18 22:13:38  opentelemetry-demo-frauddetectionservice-64cb6...
# 3  2024-04-22 12:30:14  opentelemetry-demo-frauddetectionservice-64cb6...
# 4  2024-04-22 15:54:45  opentelemetry-demo-recommendationservice-7697d...
#
#    CPU Usage (%)  Memory Usage (%) Pod Status  Pod Restarts  Ready Containers  \
# 0       0.230313         53.101612    Running             0                 1
# 1      14.612577          0.141409    Running             2                 1
# 2       0.603365         12.191371    Running             0                 1
# 3       0.077004          0.201204    Unknown             0                 0
# 4       1.060736         43.678164    Running             0                 1
#
# ...

# %%
df=df.drop(columns=['Memory Usage (Swap) (MB)'])

# %%
df.head()
# Out:
#              Timestamp                                           Pod Name  \
# 0  2024-04-19 21:05:48          opentelemetry-demo-redis-68779558bb-4mjtr
# 1  2024-04-19 20:58:41       opentelemetry-demo-frontend-76f486559f-szlsh
# 2  2024-04-18 22:13:38  opentelemetry-demo-frauddetectionservice-64cb6...
# 3  2024-04-22 12:30:14  opentelemetry-demo-frauddetectionservice-64cb6...
# 4  2024-04-22 15:54:45  opentelemetry-demo-recommendationservice-7697d...
#
#    CPU Usage (%)  Memory Usage (%) Pod Status  Pod Restarts  Ready Containers  \
# 0       0.230313         53.101612    Running             0                 1
# 1      14.612577          0.141409    Running             2                 1
# 2       0.603365         12.191371    Running             0                 1
# 3       0.077004          0.201204    Unknown             0                 0
# 4       1.060736         43.678164    Running             0                 1
#
# ...

# %%
memory_usage_swap_mb=0

# %%
c=set(df['Pod Status'])

# %%
c
# Out:
# {'ContainerCreating',
#  'CrashLoopBackOff',
#  'Error',
#  'NotFound',
#  'Pending',
#  'Running',
#  'Unknown'}

# %%
status_mapping = {
    'ContainerCreating': 0,
    'CrashLoopBackOff': 1,
    'Error': 2,
    'NotFound': 3,
    'Pending': 4,
    'Running': 5,
    'Unknown': 6
}
Pod_Status = "Pod Status"  # Replace with the actual column name
df[Pod_Status] = df[Pod_Status].map(status_mapping)

# %%
df.head()
# Out:
#              Timestamp                                           Pod Name  \
# 0  2024-04-19 21:05:48          opentelemetry-demo-redis-68779558bb-4mjtr
# 1  2024-04-19 20:58:41       opentelemetry-demo-frontend-76f486559f-szlsh
# 2  2024-04-18 22:13:38  opentelemetry-demo-frauddetectionservice-64cb6...
# 3  2024-04-22 12:30:14  opentelemetry-demo-frauddetectionservice-64cb6...
# 4  2024-04-22 15:54:45  opentelemetry-demo-recommendationservice-7697d...
#
#    CPU Usage (%)  Memory Usage (%)  Pod Status  Pod Restarts  \
# 0       0.230313         53.101612           5             0
# 1      14.612577          0.141409           5             2
# 2       0.603365         12.191371           5             0
# 3       0.077004          0.201204           6             0
# 4       1.060736         43.678164           5             0
#
#    Ready Containers  Total Containers    Pod Event Type Pod Event Reason  \
# 0                 1                 1  No recent events           Pulled
# ...

# %%
d=set(df['Pod Event Type'])

# %%
d
# Out:
# {'No recent events', 'Normal', 'Warning'}

# %%
event_type_mapping = {
    'No recent events': 0,
    'Normal': 1,
    'Warning': 2
}
df['Pod Event Type'] = df['Pod Event Type'].map(event_type_mapping)

# %%
df.head()
# Out:
#              Timestamp                                           Pod Name  \
# 0  2024-04-19 21:05:48          opentelemetry-demo-redis-68779558bb-4mjtr
# 1  2024-04-19 20:58:41       opentelemetry-demo-frontend-76f486559f-szlsh
# 2  2024-04-18 22:13:38  opentelemetry-demo-frauddetectionservice-64cb6...
# 3  2024-04-22 12:30:14  opentelemetry-demo-frauddetectionservice-64cb6...
# 4  2024-04-22 15:54:45  opentelemetry-demo-recommendationservice-7697d...
#
#    CPU Usage (%)  Memory Usage (%)  Pod Status  Pod Restarts  \
# 0       0.230313         53.101612           5             0
# 1      14.612577          0.141409           5             2
# 2       0.603365         12.191371           5             0
# 3       0.077004          0.201204           6             0
# 4       1.060736         43.678164           5             0
#
#    Ready Containers  Total Containers  Pod Event Type Pod Event Reason  \
# 0                 1                 1               0           Pulled
# ...

# %%
e=set(df['Pod Event Reason'])
e
# Out:
# {'BackOff',
#  'Created',
#  'Killing',
#  'NodeNotReady',
#  'Pulled',
#  'Pulling',
#  'Started'}

# %%
event_reason_mapping = {
    'BackOff': 0,
    'Created': 1,
    'Killing': 2,
    'NodeNotReady': 3,
    'Pulled': 4,
    'Pulling': 5,
    'Started': 6
}
df['Pod Event Reason'] = df['Pod Event Reason'].map(event_reason_mapping)

# %%
df.head()
# Out:
#              Timestamp                                           Pod Name  \
# 0  2024-04-19 21:05:48          opentelemetry-demo-redis-68779558bb-4mjtr
# 1  2024-04-19 20:58:41       opentelemetry-demo-frontend-76f486559f-szlsh
# 2  2024-04-18 22:13:38  opentelemetry-demo-frauddetectionservice-64cb6...
# 3  2024-04-22 12:30:14  opentelemetry-demo-frauddetectionservice-64cb6...
# 4  2024-04-22 15:54:45  opentelemetry-demo-recommendationservice-7697d...
#
#    CPU Usage (%)  Memory Usage (%)  Pod Status  Pod Restarts  \
# 0       0.230313         53.101612           5             0
# 1      14.612577          0.141409           5             2
# 2       0.603365         12.191371           5             0
# 3       0.077004          0.201204           6             0
# 4       1.060736         43.678164           5             0
#
#    Ready Containers  Total Containers  Pod Event Type  Pod Event Reason  \
# 0                 1                 1               0                 4
# ...

# %%
f=set(df['Pod Event Source'])
f
# Out:
# {'kubelet', 'node-controller'}

# %%
event_source_mapping = {
    'kubelet': 0,
    'node-controller': 1
}
df['Pod Event Source'] = df['Pod Event Source'].map(event_source_mapping)

# %%
df.head()
# Out:
#              Timestamp                                           Pod Name  \
# 0  2024-04-19 21:05:48          opentelemetry-demo-redis-68779558bb-4mjtr
# 1  2024-04-19 20:58:41       opentelemetry-demo-frontend-76f486559f-szlsh
# 2  2024-04-18 22:13:38  opentelemetry-demo-frauddetectionservice-64cb6...
# 3  2024-04-22 12:30:14  opentelemetry-demo-frauddetectionservice-64cb6...
# 4  2024-04-22 15:54:45  opentelemetry-demo-recommendationservice-7697d...
#
#    CPU Usage (%)  Memory Usage (%)  Pod Status  Pod Restarts  \
# 0       0.230313         53.101612           5             0
# 1      14.612577          0.141409           5             2
# 2       0.603365         12.191371           5             0
# 3       0.077004          0.201204           6             0
# 4       1.060736         43.678164           5             0
#
#    Ready Containers  Total Containers  Pod Event Type  Pod Event Reason  \
# 0                 1                 1               0                 4
# ...

# %%
g=set(df['Pod Event Message'])
g
# Out:
# {'Back-off restarting failed container checkoutservice in pod opentelemetry-demo-checkoutservice-7d546c4b8-bclj2_otel-demo(cef5888e-0b24-49b9-a631-8120513a5fd9)',
#  'Container image "ghcr.io/open-telemetry/demo:1.8.0-adservice" already present on machine',
#  'Container image "ghcr.io/open-telemetry/demo:1.8.0-cartservice" already present on machine',
#  'Container image "ghcr.io/open-telemetry/demo:1.8.0-checkoutservice" already present on machine',
#  'Container image "ghcr.io/open-telemetry/demo:1.8.0-emailservice" already present on machine',
#  'Container image "ghcr.io/open-telemetry/demo:1.8.0-loadgenerator" already present on machine',
#  'Container image "ghcr.io/open-telemetry/demo:1.8.0-recommendationservice" already present on machine',
#  'Created container frontend',
#  'Created container frontendproxy',
#  'Created container quoteservice',
#  'Created container wait-for-kafka',
#  'Node is not ready',
#  'Pulling image "busybox:latest"',
# ...

# %%
g
event_message_mapping = {
    'Back-off restarting failed container checkoutservice in pod opentelemetry-demo-checkoutservice-7d546c4b8-bclj2_otel-demo(cef5888e-0b24-49b9-a631-8120513a5fd9)': 0,
    'Container image "ghcr.io/open-telemetry/demo:1.8.0-adservice" already present on machine': 1,
    'Container image "ghcr.io/open-telemetry/demo:1.8.0-cartservice" already present on machine': 1,
    'Container image "ghcr.io/open-telemetry/demo:1.8.0-checkoutservice" already present on machine': 1,
    'Container image "ghcr.io/open-telemetry/demo:1.8.0-emailservice" already present on machine': 1,
    'Container image "ghcr.io/open-telemetry/demo:1.8.0-loadgenerator" already present on machine': 1,
    'Container image "ghcr.io/open-telemetry/demo:1.8.0-recommendationservice" already present on machine': 1,
    'Created container frontend': 2,
    'Created container frontendproxy': 2,
    'Created container quoteservice': 2,
    'Created container wait-for-kafka': 2,
    'Node is not ready': 3,
    'Pulling image "busybox:latest"': 4,
    'Pulling image "ghcr.io/open-telemetry/demo:1.8.0-kafka"': 4,
    'Pulling image "ghcr.io/open-telemetry/demo:1.8.0-paymentservice"': 4,
    'Pulling image "ghcr.io/open-telemetry/demo:1.8.0-recommendationservice"':4,
    'Started container currencyservice': 5,
    'Started container ffspostgres': 5,
    'Started container frontendproxy': 5,
    'Started container kafka': 5,
    'Started container paymentservice': 5,
    'Started container productcatalogservice': 5,
    'Started container recommendationservice': 5,
    'Started container redis': 5,
    'Started container shippingservice': 5,
    'Started container wait-for-kafka': 5,
    'Stopping container kafka': 6,
    'Successfully pulled image "busybox:latest" in 469ms (469ms including waiting)': 7,
    'Successfully pulled image "ghcr.io/open-telemetry/demo:1.8.0-accountingservice" in 1.596s (1.771s including waiting)': 7,
    'Successfully pulled image "ghcr.io/open-telemetry/demo:1.8.0-checkoutservice" in 1.179s (1.179s including waiting)': 7,
    'Successfully pulled image "ghcr.io/open-telemetry/demo:1.8.0-frauddetectionservice" in 13.582s (13.582s including waiting)': 7,
    'Successfully pulled image "ghcr.io/open-telemetry/demo:1.8.0-recommendationservice" in 9.409s (47.265s including waiting)':7,
    'Successfully pulled image "ghcr.io/open-telemetry/demo:1.8.0-shippingservice" in 1.037s (20.544s including waiting)': 7,
    'Successfully pulled image "redis:7.2-alpine" in 1.853s (1.853s including waiting)': 7
}

# %%
df.head()
# Out:
#              Timestamp                                           Pod Name  \
# 0  2024-04-19 21:05:48          opentelemetry-demo-redis-68779558bb-4mjtr
# 1  2024-04-19 20:58:41       opentelemetry-demo-frontend-76f486559f-szlsh
# 2  2024-04-18 22:13:38  opentelemetry-demo-frauddetectionservice-64cb6...
# 3  2024-04-22 12:30:14  opentelemetry-demo-frauddetectionservice-64cb6...
# 4  2024-04-22 15:54:45  opentelemetry-demo-recommendationservice-7697d...
#
#    CPU Usage (%)  Memory Usage (%)  Pod Status  Pod Restarts  \
# 0       0.230313         53.101612           5             0
# 1      14.612577          0.141409           5             2
# 2       0.603365         12.191371           5             0
# 3       0.077004          0.201204           6             0
# 4       1.060736         43.678164           5             0
#
#    Ready Containers  Total Containers  Pod Event Type  Pod Event Reason  \
# 0                 1                 1               0                 4
# ...

# %%
pd.set_option("display.max_columns", None)

# Print all columns with df.head()
print(df.head())
# Out:
#              Timestamp                                           Pod Name  \
# 0  2024-04-19 21:05:48          opentelemetry-demo-redis-68779558bb-4mjtr
# 1  2024-04-19 20:58:41       opentelemetry-demo-frontend-76f486559f-szlsh
# 2  2024-04-18 22:13:38  opentelemetry-demo-frauddetectionservice-64cb6...
# 3  2024-04-22 12:30:14  opentelemetry-demo-frauddetectionservice-64cb6...
# 4  2024-04-22 15:54:45  opentelemetry-demo-recommendationservice-7697d...
#
#    CPU Usage (%)  Memory Usage (%)  Pod Status  Pod Restarts  \
# 0       0.230313         53.101612           5             0
# 1      14.612577          0.141409           5             2
# 2       0.603365         12.191371           5             0
# 3       0.077004          0.201204           6             0
# 4       1.060736         43.678164           5             0
#
#    Ready Containers  Total Containers  Pod Event Type  Pod Event Reason  \
# 0                 1                 1               0                 4
# ...

# %%
h=set(df['Node Name'])
h
# Out:
# {'Unknown',
#  'aks-npubuntu-25645003-vmss000001',
#  'aks-npubuntu-25645003-vmss000002',
#  'aks-npubuntu-25645003-vmss000003',
#  'aks-npubuntu-25645003-vmss000004'}

# %%
node_name_mapping = {
    'Unknown': 0,
    'aks-npubuntu-25645003-vmss000001': 1,
    'aks-npubuntu-25645003-vmss000002': 2,
    'aks-npubuntu-25645003-vmss000003': 3,
    'aks-npubuntu-25645003-vmss000004': 4
}



# Apply mapping to 'Node Name' column
df['Node Name'] = df['Node Name'].map(node_name_mapping)

# %%
df.head()
# Out:
#              Timestamp                                           Pod Name  \
# 0  2024-04-19 21:05:48          opentelemetry-demo-redis-68779558bb-4mjtr
# 1  2024-04-19 20:58:41       opentelemetry-demo-frontend-76f486559f-szlsh
# 2  2024-04-18 22:13:38  opentelemetry-demo-frauddetectionservice-64cb6...
# 3  2024-04-22 12:30:14  opentelemetry-demo-frauddetectionservice-64cb6...
# 4  2024-04-22 15:54:45  opentelemetry-demo-recommendationservice-7697d...
#
#    CPU Usage (%)  Memory Usage (%)  Pod Status  Pod Restarts  \
# 0       0.230313         53.101612           5             0
# 1      14.612577          0.141409           5             2
# 2       0.603365         12.191371           5             0
# 3       0.077004          0.201204           6             0
# 4       1.060736         43.678164           5             0
#
#    Ready Containers  Total Containers  Pod Event Type  Pod Event Reason  \
# 0                 1                 1               0                 4
# ...

# %%
i=set(df['Event Reason'])

# %%
i
# Out:
# {'ContainerRuntimeIsUp',
#  'KubeletIsUp',
#  'No recent events',
#  'NoVMEventScheduled',
#  'NodeNotReady',
#  'OOMKilling',
#  'RedeployScheduled',
#  'RegisteredNode'}

# %%
event_reason_mapping = {
    'ContainerRuntimeIsUp': 0,
    'KubeletIsUp': 1,
    'No recent events': 2,
    'NoVMEventScheduled': 3,
    'NodeNotReady': 4,
    'OOMKilling': 5,
    'RedeployScheduled': 6,
    'RegisteredNode': 7
}



# Apply mapping to 'Event Reason' column
df['Event Reason'] = df['Event Reason'].map(event_reason_mapping)

# %%
df.head()
# Out:
#              Timestamp                                           Pod Name  \
# 0  2024-04-19 21:05:48          opentelemetry-demo-redis-68779558bb-4mjtr
# 1  2024-04-19 20:58:41       opentelemetry-demo-frontend-76f486559f-szlsh
# 2  2024-04-18 22:13:38  opentelemetry-demo-frauddetectionservice-64cb6...
# 3  2024-04-22 12:30:14  opentelemetry-demo-frauddetectionservice-64cb6...
# 4  2024-04-22 15:54:45  opentelemetry-demo-recommendationservice-7697d...
#
#    CPU Usage (%)  Memory Usage (%)  Pod Status  Pod Restarts  \
# 0       0.230313         53.101612           5             0
# 1      14.612577          0.141409           5             2
# 2       0.603365         12.191371           5             0
# 3       0.077004          0.201204           6             0
# 4       1.060736         43.678164           5             0
#
#    Ready Containers  Total Containers  Pod Event Type  Pod Event Reason  \
# 0                 1                 1               0                 4
# ...

# %%
j=set(df['Event Source'])
j
# Out:
# {'container-runtime-custom-plugin-monitor',
#  'custom-scheduledevents-consolidated-condition-plugin-monitor',
#  'custom-scheduledevents-consolidated-plugin-monitor',
#  'kernel-monitor',
#  'kubelet-custom-plugin-monitor',
#  'node-controller'}

# %%
event_source_mapping = {
    'container-runtime-custom-plugin-monitor': 0,
    'custom-scheduledevents-consolidated-condition-plugin-monitor': 1,
    'custom-scheduledevents-consolidated-plugin-monitor': 2,
    'kernel-monitor': 3,
    'kubelet-custom-plugin-monitor': 4,
    'node-controller': 5
}



# Apply mapping to 'Event Source' column
df['Event Source'] = df['Event Source'].map(event_source_mapping)

# %%
df.head()
# Out:
#              Timestamp                                           Pod Name  \
# 0  2024-04-19 21:05:48          opentelemetry-demo-redis-68779558bb-4mjtr
# 1  2024-04-19 20:58:41       opentelemetry-demo-frontend-76f486559f-szlsh
# 2  2024-04-18 22:13:38  opentelemetry-demo-frauddetectionservice-64cb6...
# 3  2024-04-22 12:30:14  opentelemetry-demo-frauddetectionservice-64cb6...
# 4  2024-04-22 15:54:45  opentelemetry-demo-recommendationservice-7697d...
#
#    CPU Usage (%)  Memory Usage (%)  Pod Status  Pod Restarts  \
# 0       0.230313         53.101612           5             0
# 1      14.612577          0.141409           5             2
# 2       0.603365         12.191371           5             0
# 3       0.077004          0.201204           6             0
# 4       1.060736         43.678164           5             0
#
#    Ready Containers  Total Containers  Pod Event Type  Pod Event Reason  \
# 0                 1                 1               0                 4
# ...

# %%
k=set(df['Event Message'])
k
# Out:
# {'(combined from similar events): Memory cgroup out of memory: Killed process 170151 (chrome) total-vm:34101760kB, anon-rss:16576kB, file-rss:2856kB, shmem-rss:0kB, UID:0 pgtables:676kB oom_score_adj:872',
#  '(combined from similar events): Memory cgroup out of memory: Killed process 228893 (ThreadPoolForeg) total-vm:1186162004kB, anon-rss:16900kB, file-rss:1808kB, shmem-rss:0kB, UID:0 pgtables:672kB oom_score_adj:872',
#  '(combined from similar events): Memory cgroup out of memory: Killed process 2777192 (ThreadPoolServi) total-vm:33917692kB, anon-rss:15960kB, file-rss:1492kB, shmem-rss:0kB, UID:0 pgtables:524kB oom_score_adj:872',
#  '(combined from similar events): Memory cgroup out of memory: Killed process 3018833 (chrome) total-vm:1186195332kB, anon-rss:33612kB, file-rss:1088kB, shmem-rss:0kB, UID:0 pgtables:852kB oom_score_adj:872',
# ...

# %%
pd.set_option("display.max_columns", None)

# Print all columns with df.head()
print(df.head())
# Out:
#              Timestamp                                           Pod Name  \
# 0  2024-04-19 21:05:48          opentelemetry-demo-redis-68779558bb-4mjtr
# 1  2024-04-19 20:58:41       opentelemetry-demo-frontend-76f486559f-szlsh
# 2  2024-04-18 22:13:38  opentelemetry-demo-frauddetectionservice-64cb6...
# 3  2024-04-22 12:30:14  opentelemetry-demo-frauddetectionservice-64cb6...
# 4  2024-04-22 15:54:45  opentelemetry-demo-recommendationservice-7697d...
#
#    CPU Usage (%)  Memory Usage (%)  Pod Status  Pod Restarts  \
# 0       0.230313         53.101612           5             0
# 1      14.612577          0.141409           5             2
# 2       0.603365         12.191371           5             0
# 3       0.077004          0.201204           6             0
# 4       1.060736         43.678164           5             0
#
#    Ready Containers  Total Containers  Pod Event Type  Pod Event Reason  \
# 0                 1                 1               0                 4
# ...

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
print(df.dtypes['Timestamp'])  # Check if it's now datetime64
# Out:
# datetime64[ns]

# %%
df.head()
# Out:
#             Timestamp                                           Pod Name  \
# 0 2024-04-19 21:05:48          opentelemetry-demo-redis-68779558bb-4mjtr
# 1 2024-04-19 20:58:41       opentelemetry-demo-frontend-76f486559f-szlsh
# 2 2024-04-18 22:13:38  opentelemetry-demo-frauddetectionservice-64cb6...
# 3 2024-04-22 12:30:14  opentelemetry-demo-frauddetectionservice-64cb6...
# 4 2024-04-22 15:54:45  opentelemetry-demo-recommendationservice-7697d...
#
#    CPU Usage (%)  Memory Usage (%)  Pod Status  Pod Restarts  \
# 0       0.230313         53.101612           5             0
# 1      14.612577          0.141409           5             2
# 2       0.603365         12.191371           5             0
# 3       0.077004          0.201204           6             0
# 4       1.060736         43.678164           5             0
#
#    Ready Containers  Total Containers  Pod Event Type  Pod Event Reason  \
# 0                 1                 1               0                 4
# ...

# %%
print(df['Timestamp'])
# Out:
# 0       2024-04-19 21:05:48
# 1       2024-04-19 20:58:41
# 2       2024-04-18 22:13:38
# 3       2024-04-22 12:30:14
# 4       2024-04-22 15:54:45
#                 ...
# 99995   2024-04-18 21:34:18
# 99996   2024-04-18 15:32:45
# 99997   2024-04-18 15:57:40
# 99998   2024-04-22 11:01:44
# 99999   2024-04-18 15:47:12
# Name: Timestamp, Length: 100000, dtype: datetime64[ns]

# %%
pd.set_option("display.max_columns", None)

# Print all columns with df.head()
print(df.head())
# Out:
#             Timestamp                                           Pod Name  \
# 0 2024-04-19 21:05:48          opentelemetry-demo-redis-68779558bb-4mjtr
# 1 2024-04-19 20:58:41       opentelemetry-demo-frontend-76f486559f-szlsh
# 2 2024-04-18 22:13:38  opentelemetry-demo-frauddetectionservice-64cb6...
# 3 2024-04-22 12:30:14  opentelemetry-demo-frauddetectionservice-64cb6...
# 4 2024-04-22 15:54:45  opentelemetry-demo-recommendationservice-7697d...
#
#    CPU Usage (%)  Memory Usage (%)  Pod Status  Pod Restarts  \
# 0       0.230313         53.101612           5             0
# 1      14.612577          0.141409           5             2
# 2       0.603365         12.191371           5             0
# 3       0.077004          0.201204           6             0
# 4       1.060736         43.678164           5             0
#
#    Ready Containers  Total Containers  Pod Event Type  Pod Event Reason  \
# 0                 1                 1               0                 4
# ...

# %%
l=set(df['Pod Name'])
l
# Out:
# {'opentelemetry-demo-accountingservice-66c8f4f95-bffj8',
#  'opentelemetry-demo-accountingservice-66c8f4f95-tvsd5',
#  'opentelemetry-demo-adservice-59f9578b7c-dfkjg',
#  'opentelemetry-demo-adservice-59f9578b7c-rg6xr',
#  'opentelemetry-demo-cartservice-56c6b98587-j4hx9',
#  'opentelemetry-demo-cartservice-56c6b98587-tsfjc',
#  'opentelemetry-demo-checkoutservice-7d546c4b8-bclj2',
#  'opentelemetry-demo-checkoutservice-7d546c4b8-bh4mp',
#  'opentelemetry-demo-currencyservice-77f76b5c58-2xk6g',
#  'opentelemetry-demo-currencyservice-77f76b5c58-tzrrb',
#  'opentelemetry-demo-emailservice-dd9b599db-hctwt',
#  'opentelemetry-demo-emailservice-dd9b599db-hqtxc',
#  'opentelemetry-demo-featureflagservice-b69bd5844-dg87d',
#  'opentelemetry-demo-ffspostgres-7464b97d47-qz9zg',
#  'opentelemetry-demo-ffspostgres-7464b97d47-vjbrm',
#  'opentelemetry-demo-frauddetectionservice-64cb68b994-4smd7',
#  'opentelemetry-demo-frauddetectionservice-64cb68b994-hll2h',
# ...

# %%
pod_name_mapping = {
    'opentelemetry-demo-accountingservice-66c8f4f95-bffj8': 0,
    'opentelemetry-demo-accountingservice-66c8f4f95-tvsd5': 1,
    'opentelemetry-demo-adservice-59f9578b7c-dfkjg': 2,
    'opentelemetry-demo-adservice-59f9578b7c-rg6xr': 3,
    'opentelemetry-demo-cartservice-56c6b98587-j4hx9': 4,
    'opentelemetry-demo-cartservice-56c6b98587-tsfjc': 5,
    'opentelemetry-demo-checkoutservice-7d546c4b8-bclj2': 6,
    'opentelemetry-demo-checkoutservice-7d546c4b8-bh4mp': 7,
    'opentelemetry-demo-currencyservice-77f76b5c58-2xk6g': 8,
    'opentelemetry-demo-currencyservice-77f76b5c58-tzrrb': 9,
    'opentelemetry-demo-emailservice-dd9b599db-hctwt': 10,
    'opentelemetry-demo-emailservice-dd9b599db-hqtxc': 11,
    'opentelemetry-demo-featureflagservice-b69bd5844-dg87d': 12,
    'opentelemetry-demo-ffspostgres-7464b97d47-qz9zg': 13,
    'opentelemetry-demo-ffspostgres-7464b97d47-vjbrm': 14,
    'opentelemetry-demo-frauddetectionservice-64cb68b994-4smd7': 15,
    'opentelemetry-demo-frauddetectionservice-64cb68b994-hll2h': 16,
    'opentelemetry-demo-frontend-76f486559f-qz9ft': 17,
    'opentelemetry-demo-frontend-76f486559f-szlsh': 18,
    'opentelemetry-demo-frontend-76f486559f-zfwsj': 19,
    'opentelemetry-demo-frontendproxy-588c77dd7c-l4wcd': 20,
    'opentelemetry-demo-frontendproxy-588c77dd7c-w78jm': 21,
    'opentelemetry-demo-grafana-6c54b4947d-dd695': 22,
    'opentelemetry-demo-jaeger-7c9549545c-8c78r': 23,
    'opentelemetry-demo-kafka-bf49b64c9-mdm2l': 24,
    'opentelemetry-demo-kafka-bf49b64c9-nmsmn': 25,
    'opentelemetry-demo-loadgenerator-6dc4487b75-np9vz': 26,
    'opentelemetry-demo-otelcol-5bc9b48954-4psc7': 27,
    'opentelemetry-demo-paymentservice-5fcfd5559c-kx9hl': 28,
    'opentelemetry-demo-paymentservice-5fcfd5559c-skr74': 29,
    'opentelemetry-demo-productcatalogservice-84f77b664d-5z4zl': 30,
    'opentelemetry-demo-productcatalogservice-84f77b664d-bswjj': 31,
    'opentelemetry-demo-prometheus-server-74999b59c4-f4k44': 32,
    'opentelemetry-demo-quoteservice-6fd674f94f-gsm9b': 33,
    'opentelemetry-demo-quoteservice-6fd674f94f-j85d8': 34,
    'opentelemetry-demo-quoteservice-6fd674f94f-x9dhq': 35,
    'opentelemetry-demo-recommendationservice-7697d65f77-8vnrq': 36,
    'opentelemetry-demo-recommendationservice-7697d65f77-bqgzd': 37,
    'opentelemetry-demo-recommendationservice-7697d65f77-j75rv': 38,
    'opentelemetry-demo-recommendationservice-7697d65f77-t2mqp': 39,
    'opentelemetry-demo-recommendationservice-7697d65f77-xnkmr': 40,
    'opentelemetry-demo-redis-68779558bb-4mjtr': 41,
    'opentelemetry-demo-redis-68779558bb-cvc8j': 42,
    'opentelemetry-demo-redis-68779558bb-gmw7r': 43,
    'opentelemetry-demo-shippingservice-86ccddbd5b-6w8z7': 44,
    'opentelemetry-demo-shippingservice-86ccddbd5b-9hjhw': 45,
    'opentelemetry-demo-shippingservice-86ccddbd5b-b7sc9': 46,
    'otel-demo-opensearch-0': 47
}

# Apply mapping to 'Pod Name' column
df['Pod Name'] = df['Pod Name'].map(pod_name_mapping)

# %%
pd.set_option("display.max_columns", None)

# Print all columns with df.head()
print(df.head())
# Out:
#             Timestamp  Pod Name  CPU Usage (%)  Memory Usage (%)  Pod Status  \
# 0 2024-04-19 21:05:48        41       0.230313         53.101612           5
# 1 2024-04-19 20:58:41        18      14.612577          0.141409           5
# 2 2024-04-18 22:13:38        15       0.603365         12.191371           5
# 3 2024-04-22 12:30:14        16       0.077004          0.201204           6
# 4 2024-04-22 15:54:45        36       1.060736         43.678164           5
#
#    Pod Restarts  Ready Containers  Total Containers  Pod Event Type  \
# 0             0                 1                 1               0
# 1             2                 1                 1               1
# 2             0                 1                 1               1
# 3             0                 0                 0               0
# 4             0                 1                 1               0
#
#    Pod Event Reason Pod Event Age  Pod Event Source  \
# ...

# %%
try:
    import matplotlib.pyplot as plt
    import seaborn as sns
except ImportError:
    import subprocess
    import sys
    subprocess.check_call([sys.executable, "-m", "pip", "install", "matplotlib", "seaborn"])
    import matplotlib.pyplot as plt
    import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df["CPU Usage (%)"], bins=30, kde=True, color="blue")
plt.xlabel("CPU Usage (%)")
plt.ylabel("Frequency")
plt.title("Distribution of CPU Usage (%) in Kubernetes Pods")
plt.show()

# %%
print(df["CPU Usage (%)"].describe())
# Out:
# count    100000.000000
# mean          1.034169
# std           2.869768
# min           0.000000
# 25%           0.011043
# 50%           0.095716
# 75%           0.641537
# max          30.030964
# Name: CPU Usage (%), dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df["Memory Usage (%)"], bins=30, kde=True, color="blue")
plt.xlabel("Memory Usage (%)")
plt.ylabel("Frequency")
plt.title("Distribution of Memory Usage (%) in Kubernetes Pods")
plt.show()

# %%
df["CPU Usage (%)"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["CPU Usage (%)"] = df["CPU Usage (%)"].round(3)

# %%
df["Memory Usage (%)"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Memory Usage (%)"] = df["Memory Usage (%)"].round(3)

# %%
df["Memory Usage (MB)"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Memory Usage (MB)"] = df["Memory Usage (MB)"].round(3)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df["Active Memory Requests (MB)"], bins=30, kde=True, color="blue")
plt.xlabel("Active Memory Requests (MB)")
plt.ylabel("Frequency")
plt.title("Distribution of Active Memory Requests (MB) in Kubernetes Pods")
plt.show()

# %%
df["Active Memory Requests (MB)"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Memory Requests (%)"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Memory Requests (%)"] = df["Memory Requests (%)"].round(3)

# %%
df["Active Memory Limits (MB)emory Limits Utilization (%)"].isnull().sum()
# Out:
# np.int64(0)

# %%
df[['Memory Usage (MB)', 'Memory Usage (MB).1']].describe()
df[['Memory Usage (MB)', 'Memory Usage (MB).1']].corr()
# Out:
#                      Memory Usage (MB)  Memory Usage (MB).1
# Memory Usage (MB)             1.000000             0.410629
# Memory Usage (MB).1           0.410629             1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 5))
sns.histplot(df['Memory Usage (MB)'], kde=True, color='blue', label='Memory Usage (MB)')
sns.histplot(df['Memory Usage (MB).1'], kde=True, color='red', label='Memory Usage (MB).1', alpha=0.6)
plt.legend()
plt.title('Distribution of Memory Usage Columns')
plt.show()

# %%
df[['Memory Usage (MB)', 'Memory Usage (MB).1']].describe()
# Out:
#        Memory Usage (MB)  Memory Usage (MB).1
# count      100000.000000        100000.000000
# mean           60.031124            39.108911
# std           132.194013            25.269007
# min             0.145000             0.201172
# 25%             8.420000            13.064679
# 50%            19.769000            41.278646
# 75%            44.393000            54.471551
# max          1598.730000           114.962869

# %%
df["Memory Usage (MB).1"] = df["Memory Usage (MB).1"].round(3)

# %%
df["Memory Usage (MB).1"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Memory Usage (Cache) (MB)"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Network Receive Bytes"] = df["Network Receive Bytes"].round(3)

# %%
df["Network Receive Packets (p/s)"] = df["Network Receive Packets (p/s)"].round(3)

# %%
df["Network Transmit Packets (p/s)"] = df["Network Transmit Packets (p/s)"].round(3)

# %%
df["Network Receive Packets Dropped (p/s)"] = df["Network Receive Packets Dropped (p/s)"].round(3)

# %%
df["FS Reads Total (MB)"] = df["FS Reads Total (MB)"].round(3)

# %%
df["FS Writes Total (MB)"] = df["FS Writes Total (MB)"].round(3)

# %%
# Selecting the last 6 columns
last_six_columns = df.iloc[:, -6:]

# Counting occurrences of 0.0 values in each column
zero_counts = (last_six_columns == 0.0).sum()

# Summing across all six columns
total_zero_count = zero_counts.sum()

# Display results
print("Zero counts per column:")
print(zero_counts)
print("\nTotal number of 0.0 values across all six columns:", total_zero_count)
# Out:
# Zero counts per column:
# FS Reads Total (MB)                 70648
# FS Writes Total (MB)                37218
# FS Reads/Writes Total (MB)          45551
# FS Reads Bytes Total (MB)           35925
# FS Writes Bytes Total (MB)          74442
# FS Reads/Writes Bytes Total (MB)    50508
# dtype: int64
#
# Total number of 0.0 values across all six columns: 314292

# %%
df["FS Reads/Writes Total (MB)"] = df["FS Reads/Writes Total (MB)"].round(3)

# %%
df=df.drop(columns=['FS Reads Bytes Total (MB)'])

# %%
df=df.drop(columns=['FS Writes Bytes Total (MB)'])

# %%
df=df.drop(columns=['FS Reads/Writes Bytes Total (MB)'])

# %%
pd.set_option("display.max_columns", None)

# Print all columns with df.head()
print(df.head())
# Out:
#             Timestamp  Pod Name  CPU Usage (%)  Memory Usage (%)  Pod Status  \
# 0 2024-04-19 21:05:48        41          0.230            53.102           5
# 1 2024-04-19 20:58:41        18         14.613             0.141           5
# 2 2024-04-18 22:13:38        15          0.603            12.191           5
# 3 2024-04-22 12:30:14        16          0.077             0.201           6
# 4 2024-04-22 15:54:45        36          1.061            43.678           5
#
#    Pod Restarts  Ready Containers  Total Containers  Pod Event Type  \
# 0             0                 1                 1               0
# 1             2                 1                 1               1
# 2             0                 1                 1               1
# 3             0                 0                 0               0
# 4             0                 1                 1               0
#
#    Pod Event Reason Pod Event Age  Pod Event Source  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 5))
sns.histplot(df['Memory Requests (%)'], kde=True, color='blue', label='Memory Requests (%)')
sns.histplot(df['Memory Usage (MB).1'], kde=True, color='red', label='Memory Usage (MB).1', alpha=0.6)
plt.legend()
plt.title('Distribution of Memory Usage Columns')
plt.show()

# %%
# df.to_csv('guidewire.csv')

# %%
df=df.drop(columns=['Memory Usage (MB).1'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 5))
sns.histplot(df['Active Memory Requests (MB)'], kde=True, color='blue', label='Active Memory Requests (MB)')
sns.histplot(df['Active Memory Limits (MB)emory Limits Utilization (%)'], kde=True, color='red', label='Active Memory Limits (MB)emory Limits Utilization (%)', alpha=0.6)
plt.legend()
plt.title('Distribution of Memory Usage Columns')
plt.show()

# %%
df=df.drop(columns=['Active Memory Limits (MB)emory Limits Utilization (%)'])

# %%
pd.set_option("display.max_columns", None)

# Print all columns with df.head()
print(df.head())
# Out:
#             Timestamp  Pod Name  CPU Usage (%)  Memory Usage (%)  Pod Status  \
# 0 2024-04-19 21:05:48        41          0.230            53.102           5
# 1 2024-04-19 20:58:41        18         14.613             0.141           5
# 2 2024-04-18 22:13:38        15          0.603            12.191           5
# 3 2024-04-22 12:30:14        16          0.077             0.201           6
# 4 2024-04-22 15:54:45        36          1.061            43.678           5
#
#    Pod Restarts  Ready Containers  Total Containers  Pod Event Type  \
# 0             0                 1                 1               0
# 1             2                 1                 1               1
# 2             0                 1                 1               1
# 3             0                 0                 0               0
# 4             0                 1                 1               0
#
#    Pod Event Reason Pod Event Age  Pod Event Source  \
# ...

# %%
df=df.drop(columns=['FS Reads Total (MB)'])

# %%
df=df.drop(columns=['FS Writes Total (MB)'])

# %%
df=df.drop(columns=['FS Reads/Writes Total (MB)'])

# %%
pd.set_option("display.max_columns", None)

# Print all columns with df.head()
print(df.head())
# Out:
#             Timestamp  Pod Name  CPU Usage (%)  Memory Usage (%)  Pod Status  \
# 0 2024-04-19 21:05:48        41          0.230            53.102           5
# 1 2024-04-19 20:58:41        18         14.613             0.141           5
# 2 2024-04-18 22:13:38        15          0.603            12.191           5
# 3 2024-04-22 12:30:14        16          0.077             0.201           6
# 4 2024-04-22 15:54:45        36          1.061            43.678           5
#
#    Pod Restarts  Ready Containers  Total Containers  Pod Event Type  \
# 0             0                 1                 1               0
# 1             2                 1                 1               1
# 2             0                 1                 1               1
# 3             0                 0                 0               0
# 4             0                 1                 1               0
#
#    Pod Event Reason Pod Event Age  Pod Event Source  \
# ...

# %%
# df.to_csv('guidewire1.csv')

# %%
df.dtypes
# Out:
# Timestamp                                 datetime64[ns]
# Pod Name                                           int64
# CPU Usage (%)                                    float64
# Memory Usage (%)                                 float64
# Pod Status                                         int64
# Pod Restarts                                       int64
# Ready Containers                                   int64
# Total Containers                                   int64
# Pod Event Type                                     int64
# Pod Event Reason                                   int64
# Pod Event Age                                     object
# Pod Event Source                                   int64
# Pod Event Message                                 object
# Node Name                                          int64
# Event Reason                                       int64
# Event Age                                         object
# ...

# %%
# Sample Data
f = pd.DataFrame({'Event Age': ['00:24:58', '12:30:45', '01:15:20', '00:00:05']})

# Convert to timedelta
df['Event Age'] = pd.to_timedelta(df['Event Age'])

# %%
df.dtypes
# Out:
# Timestamp                                  datetime64[ns]
# Pod Name                                            int64
# CPU Usage (%)                                     float64
# Memory Usage (%)                                  float64
# Pod Status                                          int64
# Pod Restarts                                        int64
# Ready Containers                                    int64
# Total Containers                                    int64
# Pod Event Type                                      int64
# Pod Event Reason                                    int64
# Pod Event Age                                      object
# Pod Event Source                                    int64
# Pod Event Message                                  object
# Node Name                                           int64
# Event Reason                                        int64
# Event Age                                 timedelta64[ns]
# ...

# %%
# Sample Data
g = pd.DataFrame({'Pod Event Age': ['00:24:58', '12:30:45', '01:15:20', '00:00:05']})

# Convert to timedelta
df['Pod Event Age'] = pd.to_timedelta(df['Pod Event Age'])

# %%
df.dtypes
# Out:
# Timestamp                                  datetime64[ns]
# Pod Name                                            int64
# CPU Usage (%)                                     float64
# Memory Usage (%)                                  float64
# Pod Status                                          int64
# Pod Restarts                                        int64
# Ready Containers                                    int64
# Total Containers                                    int64
# Pod Event Type                                      int64
# Pod Event Reason                                    int64
# Pod Event Age                             timedelta64[ns]
# Pod Event Source                                    int64
# Pod Event Message                                  object
# Node Name                                           int64
# Event Reason                                        int64
# Event Age                                 timedelta64[ns]
# ...

# %%
df.head()
# Out:
#             Timestamp  Pod Name  CPU Usage (%)  Memory Usage (%)  Pod Status  \
# 0 2024-04-19 21:05:48        41          0.230            53.102           5
# 1 2024-04-19 20:58:41        18         14.613             0.141           5
# 2 2024-04-18 22:13:38        15          0.603            12.191           5
# 3 2024-04-22 12:30:14        16          0.077             0.201           6
# 4 2024-04-22 15:54:45        36          1.061            43.678           5
#
#    Pod Restarts  Ready Containers  Total Containers  Pod Event Type  \
# 0             0                 1                 1               0
# 1             2                 1                 1               1
# 2             0                 1                 1               1
# 3             0                 0                 0               0
# 4             0                 1                 1               0
#
#    Pod Event Reason   Pod Event Age  Pod Event Source  \
# ...

# %%
pd.set_option("display.max_columns", None)

# Print all columns with df.head()
print(df.head())
# Out:
#             Timestamp  Pod Name  CPU Usage (%)  Memory Usage (%)  Pod Status  \
# 0 2024-04-19 21:05:48        41          0.230            53.102           5
# 1 2024-04-19 20:58:41        18         14.613             0.141           5
# 2 2024-04-18 22:13:38        15          0.603            12.191           5
# 3 2024-04-22 12:30:14        16          0.077             0.201           6
# 4 2024-04-22 15:54:45        36          1.061            43.678           5
#
#    Pod Restarts  Ready Containers  Total Containers  Pod Event Type  \
# 0             0                 1                 1               0
# 1             2                 1                 1               1
# 2             0                 1                 1               1
# 3             0                 0                 0               0
# 4             0                 1                 1               0
#
#    Pod Event Reason   Pod Event Age  Pod Event Source  \
# ...

# %%
df.dtypes
# Out:
# Timestamp                                  datetime64[ns]
# Pod Name                                            int64
# CPU Usage (%)                                     float64
# Memory Usage (%)                                  float64
# Pod Status                                          int64
# Pod Restarts                                        int64
# Ready Containers                                    int64
# Total Containers                                    int64
# Pod Event Type                                      int64
# Pod Event Reason                                    int64
# Pod Event Age                             timedelta64[ns]
# Pod Event Source                                    int64
# Pod Event Message                                  object
# Node Name                                           int64
# Event Reason                                        int64
# Event Age                                 timedelta64[ns]
# ...

# %%
df.to_csv('guidewire1.csv')
